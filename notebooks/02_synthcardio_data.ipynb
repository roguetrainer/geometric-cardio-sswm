# %% [markdown]
# # SynthCardio Dataset Exploration
#
# Explore the synthetic cardiac geometry dataset.

# %%
import sys
sys.path.append('..')

from src.data_generator import SynthCardioDataGenerator
from src.visualization import plot_point_cloud, plot_strain_heatmap

# Generate data
generator = SynthCardioDataGenerator(n_points=100, seed=42)
data = generator.generate(batch_size=4)

print('Data shapes:')
for key, val in data.items():
    print(f'  {key}: {val.shape}')
